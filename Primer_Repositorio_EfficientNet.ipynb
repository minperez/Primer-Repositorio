# %% [markdown]
# <a href="https://colab.research.google.com/github/minperez/Primer-Repositorio/blob/main/Primer_Repositorio_EfficientNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ACTIVIDAD 4
#
# Clasificar la calidad de los crimpados eléctricos automotrices según la norma USCAR-21 usando modelo YOLOv8
